# %%
import numpy as np
import pandas as pd
df=pd.read_csv("Dogs_of_Cambridge_20240409.csv")
df.head()
# Out:
#     Dog_Name             Dog_Breed  Location_masked  Latitude_masked  \
# 0      Shula              Cockapoo              NaN          42.3863
# 1     SMOKEY                Beagle              NaN          42.3659
# 2  Josephine           Terrier mix              NaN          42.3691
# 3      Sadie  Jack Russell Terrier              NaN          42.3766
# 4    Toaster          Goldendoodle              NaN          42.3633
#
#    Longitude_masked    Neighborhood
# 0          -71.1197         Baldwin
# 1          -71.0985        The Port
# 2          -71.1041   Mid-Cambridge
# 3          -71.1251  West Cambridge
# 4          -71.1026        The Port

# %%
df["Dog_Breed"][5:10]
# Out:
# 5    Black and Tan Coonhound
# 6                  dalmation
# 7        Australian Shepherd
# 8        Australian Shepherd
# 9                Mixed Breed
# Name: Dog_Breed, dtype: object

# %%
df[["Dog_Breed","Neighborhood","Dog_Name"]][10:15]
# Out:
#                     Dog_Breed       Neighborhood Dog_Name
# 10         Australian Terrier  Neighborhood Nine  NORBERT
# 11     Labrador Retriever Mix  Neighborhood Nine    HOMER
# 12                Mixed Breed  Neighborhood Nine   Athena
# 13  American Pit Bull Terrier      Mid-Cambridge    Rusty
# 14         Labrador Retriever    North Cambridge     Lucy
